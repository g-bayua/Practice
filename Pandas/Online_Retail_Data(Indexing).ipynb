# %%
##import library
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Salinan_Online_Retail_Data.csv")

# %% [markdown]
# **Mengambil data berdasarkan index integer**

# %%
##mengambil 1 baris tertentu
df.iloc[1]
# Out:
# order_id                        C493411
# product_code                      21539
# product_name    RETRO SPOTS BUTTER DISH
# quantity                             -1
# order_date          2010-01-04 09:43:00
# price                              4.25
# customer_id                     14590.0
# Name: 1, dtype: object

# %%
#mengambil baris-baris tertentu dengan index berupa list
df.iloc[[350, 351,352]]
# Out:
#     order_id product_code                      product_name  quantity  \
# 350   493444       85129D   BEADED CRYSTAL HEART PINK SMALL         2
# 351   493444        21122  SET/10 PINK SPOTTY PARTY CANDLES         4
# 352   493444        21124  SET/10 BLUE SPOTTY PARTY CANDLES         4
#
#               order_date  price  customer_id
# 350  2010-01-04 13:47:00   1.25      16792.0
# 351  2010-01-04 13:47:00   1.25      16792.0
# 352  2010-01-04 13:47:00   1.25      16792.0

# %%
##mengambil baris dengan index berupa range
df.iloc[350:355]
# Out:
#     order_id product_code                      product_name  quantity  \
# 350   493444       85129D   BEADED CRYSTAL HEART PINK SMALL         2
# 351   493444        21122  SET/10 PINK SPOTTY PARTY CANDLES         4
# 352   493444        21124  SET/10 BLUE SPOTTY PARTY CANDLES         4
# 353   493444        21121   SET/10 RED SPOTTY PARTY CANDLES         2
# 354   493444        21737          SET 3 WICKER LOG BASKETS         1
#
#               order_date  price  customer_id
# 350  2010-01-04 13:47:00   1.25      16792.0
# 351  2010-01-04 13:47:00   1.25      16792.0
# 352  2010-01-04 13:47:00   1.25      16792.0
# 353  2010-01-04 13:47:00   1.25      16792.0
# 354  2010-01-04 13:47:00  19.95      16792.0

# %%
##mengabil semua baris kebawahnya
df.iloc[49000:]
# Out:
#        order_id product_code                     product_name  quantity  \
# 49000    498589        22168     ORGANISER WOOD ANTIQUE WHITE        12
# 49001    498589        21784                   SHOE SHINE BOX         2
# 49002    498589        21871              SAVE THE PLANET MUG        12
# 49003    498589        21877              HOME SWEET HOME MUG        12
# 49004    498590        21385  IVORY HANGING DECORATION  HEART         6
# ...         ...          ...                              ...       ...
# 461768   539991        21618   4 WILDFLOWER BOTANICAL CANDLES         1
# 461769   539991        72741            GRAND CHOCOLATECANDLE         4
# 461770   539992        21470    FLOWER VINE RAFFIA FOOD COVER         1
# 461771   539992        22258          FELT FARM ANIMAL RABBIT         1
# 461772   539992        21155            RED RETROSPOT PEG BAG         1
#
#                  order_date  price  customer_id
# 49000   2010-02-21 15:19:00   7.65      14895.0
# ...

# %%
##mengabil semua baris diatas baris tertentu
df.iloc[:10] #mengambil 10 baris pertama
# Out:
#   order_id product_code                     product_name  quantity  \
# 0   493410      TEST001          This is a test product.         5
# 1  C493411        21539          RETRO SPOTS BUTTER DISH        -1
# 2   493412      TEST001          This is a test product.         5
# 3   493413        21724  PANDA AND BUNNIES STICKER SHEET         1
# 4   493413        84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# 5   493413        21723    ALPHABET HEARTS STICKER SHEET         1
# 6   493414        21844                   RETRO SPOT MUG        36
# 7   493414        21533        RETRO SPOT LARGE MILK JUG        12
# 8   493414        37508  NEW ENGLAND CERAMIC CAKE SERVER         2
# 9   493414       35001G             HAND OPEN SHAPE GOLD         2
#
#             order_date  price  customer_id
# 0  2010-01-04 09:24:00   4.50      12346.0
# 1  2010-01-04 09:43:00   4.25      14590.0
# 2  2010-01-04 09:53:00   4.50      12346.0
# 3  2010-01-04 09:54:00   0.85          NaN
# ...

# %%
##mengambil 1 baris terakhir
df.iloc[-1]
# Out:
# order_id                       539992
# product_code                    21155
# product_name    RED RETROSPOT PEG BAG
# quantity                            1
# order_date        2010-12-23 17:41:00
# price                             2.1
# customer_id                       NaN
# Name: 461772, dtype: object

# %%
##mengambil beberapa baris terakhir
df.iloc[-5:]
# Out:
#        order_id product_code                    product_name  quantity  \
# 461768   539991        21618  4 WILDFLOWER BOTANICAL CANDLES         1
# 461769   539991        72741           GRAND CHOCOLATECANDLE         4
# 461770   539992        21470   FLOWER VINE RAFFIA FOOD COVER         1
# 461771   539992        22258         FELT FARM ANIMAL RABBIT         1
# 461772   539992        21155           RED RETROSPOT PEG BAG         1
#
#                  order_date  price  customer_id
# 461768  2010-12-23 16:49:00   1.25          NaN
# 461769  2010-12-23 16:49:00   1.45          NaN
# 461770  2010-12-23 17:41:00   3.75          NaN
# 461771  2010-12-23 17:41:00   1.25          NaN
# 461772  2010-12-23 17:41:00   2.10          NaN

# %%
##mengambil semua baris diatas beberapa baris terakhir
df.iloc[:-10]
# Out:
#        order_id product_code                      product_name  quantity  \
# 0        493410      TEST001           This is a test product.         5
# 1       C493411        21539           RETRO SPOTS BUTTER DISH        -1
# 2        493412      TEST001           This is a test product.         5
# 3        493413        21724   PANDA AND BUNNIES STICKER SHEET         1
# 4        493413        84578    ELEPHANT TOY WITH BLUE T-SHIRT         1
# ...         ...          ...                               ...       ...
# 461758   539991        22970             LONDON BUS COFFEE MUG         2
# 461759   539991        22423          REGENCY CAKESTAND 3 TIER         1
# 461760   539991        21629  SQUARE FLOOR CUSHION VINTAGE RED         1
# 461761   539991        21324      HANGING MEDINA LANTERN SMALL         2
# 461762   539991        22891              TEA FOR ONE POLKADOT         1
#
#                  order_date  price  customer_id
# ...

# %%
##mengambil berdasarkan index kolom
df.iloc[:,2]
# Out:
# 0                 This is a test product.
# 1                 RETRO SPOTS BUTTER DISH
# 2                 This is a test product.
# 3         PANDA AND BUNNIES STICKER SHEET
# 4          ELEPHANT TOY WITH BLUE T-SHIRT
#                        ...
# 461768     4 WILDFLOWER BOTANICAL CANDLES
# 461769              GRAND CHOCOLATECANDLE
# 461770      FLOWER VINE RAFFIA FOOD COVER
# 461771            FELT FARM ANIMAL RABBIT
# 461772              RED RETROSPOT PEG BAG
# Name: product_name, Length: 461773, dtype: object

# %% [markdown]
# **Mengambil baris berdasarkan non integer**

# %%
df_nointeger = df.copy()
df_nointeger.set_index('order_id', inplace=True)
df_nointeger.head()
# Out:
#          product_code                     product_name  quantity  \
# order_id
# 493410        TEST001          This is a test product.         5
# C493411         21539          RETRO SPOTS BUTTER DISH        -1
# 493412        TEST001          This is a test product.         5
# 493413          21724  PANDA AND BUNNIES STICKER SHEET         1
# 493413          84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
#
#                    order_date  price  customer_id
# order_id
# 493410    2010-01-04 09:24:00   4.50      12346.0
# C493411   2010-01-04 09:43:00   4.25      14590.0
# 493412    2010-01-04 09:53:00   4.50      12346.0
# 493413    2010-01-04 09:54:00   0.85          NaN
# 493413    2010-01-04 09:54:00   3.75          NaN

# %%
##mengambil baris menggunakan index non integer
df_nointeger.loc[['493413']]
# Out:
#          product_code                     product_name  quantity  \
# order_id
# 493413          21724  PANDA AND BUNNIES STICKER SHEET         1
# 493413          84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# 493413          21723    ALPHABET HEARTS STICKER SHEET         1
#
#                    order_date  price  customer_id
# order_id
# 493413    2010-01-04 09:54:00   0.85          NaN
# 493413    2010-01-04 09:54:00   3.75          NaN
# 493413    2010-01-04 09:54:00   0.85          NaN

# %%
##mengambil 1 kolom dengan index noninteger
df.loc[:, 'product_name']
# Out:
# 0                 This is a test product.
# 1                 RETRO SPOTS BUTTER DISH
# 2                 This is a test product.
# 3         PANDA AND BUNNIES STICKER SHEET
# 4          ELEPHANT TOY WITH BLUE T-SHIRT
#                        ...
# 461768     4 WILDFLOWER BOTANICAL CANDLES
# 461769              GRAND CHOCOLATECANDLE
# 461770      FLOWER VINE RAFFIA FOOD COVER
# 461771            FELT FARM ANIMAL RABBIT
# 461772              RED RETROSPOT PEG BAG
# Name: product_name, Length: 461773, dtype: object

# %%
##mengambil beberapa kolom dengan index noninteger
df.loc[:, ['product_name', 'quantity', 'order_date']]
# Out:
#                            product_name  quantity           order_date
# 0               This is a test product.         5  2010-01-04 09:24:00
# 1               RETRO SPOTS BUTTER DISH        -1  2010-01-04 09:43:00
# 2               This is a test product.         5  2010-01-04 09:53:00
# 3       PANDA AND BUNNIES STICKER SHEET         1  2010-01-04 09:54:00
# 4        ELEPHANT TOY WITH BLUE T-SHIRT         1  2010-01-04 09:54:00
# ...                                 ...       ...                  ...
# 461768   4 WILDFLOWER BOTANICAL CANDLES         1  2010-12-23 16:49:00
# 461769            GRAND CHOCOLATECANDLE         4  2010-12-23 16:49:00
# 461770    FLOWER VINE RAFFIA FOOD COVER         1  2010-12-23 17:41:00
# 461771          FELT FARM ANIMAL RABBIT         1  2010-12-23 17:41:00
# 461772            RED RETROSPOT PEG BAG         1  2010-12-23 17:41:00
#
# [461773 rows x 3 columns]
